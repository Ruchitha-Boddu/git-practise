# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruchitha-Boddu/git-practise/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gspread

# %%
import os
import gspread
import pandas as pd



BASE_PATH = "/content/drive/.shortcut-targets-by-id/1RhKzpMb2WCjHC0RcQALuwxe7LEBoR8SZ/Techwish - HYD - QA /Main/Test Cases Backup/Mobile/Version 1-20260205T140126Z-1-001/"

grand_total = 0

print("\n====== FILE / SHEET WISE COUNT ======\n")

for root, dirs, files in os.walk(BASE_PATH):
    for file in files:
        if file.lower().endswith((".xlsx", ".xls")) and not file.startswith("~$"):
            file_path = os.path.join(root, file)

            try:
                excel_data = pd.read_excel(file_path, sheet_name=None)

                for sheet, df in excel_data.items():
                    row_count = len(df)
                    grand_total += row_count
                    print(f" {file} | Sheet: {sheet} → {row_count} rows")

            except Exception as e:
                print(f" Error reading {file}: {e}")

        if file.lower().endswith(".gsheet") and not file.startswith("~$"):
            sheet_name = os.path.splitext(file)[0]  # remove .gsheet

            try:
                spreadsheet = client.open(sheet_name)

                for ws in spreadsheet.worksheets():
                    data = ws.get_all_records()
                    df = pd.DataFrame(data)

                    row_count = len(df)
                    grand_total += row_count
                    print(f" {sheet_name} | Sheet: {ws.title} → {row_count} rows")

            except Exception as e:
                print(f" Error reading {sheet_name}: {e}")

print("\n GRAND TOTAL TEST CASES:", grand_total)
# Out:
# ====== FILE / SHEET WISE COUNT ======
#
#  Bottom_Navigation.xlsx | Sheet: Sheet1 → 4 rows
#  Add_Gateway.xlsx | Sheet: Sheet1 → 66 rows
#  Add_Remove_Device_Generic.xlsx | Sheet: Sheet1 → 29 rows
#  Remove Prima Plus Device.xlsx | Sheet: Sheet1 → 14 rows
#  Add Prima Plus Device.xlsx | Sheet: Sheet1 → 84 rows
#  Admin_Deletion.xlsx | Sheet: Sheet1 → 15 rows
#  Internet-Tampering_Test_Cases.xlsx | Sheet: Sheet1 → 17 rows
#  Filter Devices.xlsx | Sheet: Sheet1 → 6 rows
#  Select_Unselect devices.xlsx | Sheet: Sheet1 → 14 rows
#  Search Devices.xlsx | Sheet: Sheet1 → 18 rows
#  Device info Detail Screen.xlsx | Sheet: Sheet1 → 21 rows
#  Device Change Icon Screen.xlsx | Sheet: Sheet1 → 13 rows
#  Device control for Fan.xlsx | Sheet: Sheet1 → 10 rows
#  Add Devices to Room.xlsx | Sheet: Sheet1 → 16 rows
#  Config Floor Device.xlsx | Sheet: Sheet1 → 11 rows
#  Device Security.xlsx | Sheet: Sheet1 → 80 rows
#  Favorite Scene.xlsx | Sheet: Sheet1 → 22 rows
# ...
